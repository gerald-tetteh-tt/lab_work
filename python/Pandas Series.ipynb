# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
data_2016 = pd.read_csv("AAPL-2016.csv",usecols=["Date","Volume"],index_col=0,parse_dates=True)
print(data_2016.head())
# Out:
#               Volume
# Date
# 2016-01-04  67649400
# 2016-01-05  55791000
# 2016-01-06  68457400
# 2016-01-07  81094400
# 2016-01-08  70798000

# %%
data_2016.plot()
# Out:
# <Axes: xlabel='Date'>
